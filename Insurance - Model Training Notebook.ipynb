# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Experiment 1

# %%
from pycaret.regression import *

# %%
s = setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_d2889_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2889_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d2889_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2889_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2889_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d2889_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d2889_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2889_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d2889_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_d2889_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_26e3b_row10_col0, #T_26e3b_row10_col1, #T_26e3b_row10_col2, #T_26e3b_row10_col3, #T_26e3b_row10_col4, #T_26e3b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_26e3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26e3b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_26e3b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_26e3b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_26e3b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_26e3b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_26e3b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(lr)

# %% [markdown]
# # Experiment 2

# %%
s2 = setup(data, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
# <style type="text/css">
# #T_ce60b_row9_col1, #T_ce60b_row15_col1, #T_ce60b_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce60b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce60b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ce60b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce60b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce60b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ce60b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ce60b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce60b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ce60b_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
# ...

# %%
# Now access the data properly
print("=== Dataset Information ===")
print(f"Original shape: {get_config('dataset').shape}")
print(f"Training shape: {get_config('X_train').shape}")
print(f"Test shape: {get_config('X_test').shape}")

print("\n=== Column Names ===")
print("Training columns:")
for i, col in enumerate(get_config('X_train').columns):
    print(f"{i+1}. {col}")
# Out:
# === Dataset Information ===
# Original shape: (1338, 7)
# Training shape: (936, 6)
# Test shape: (402, 6)
#
# === Column Names ===
# Training columns:
# 1. age
# 2. sex
# 3. bmi
# 4. children
# 5. smoker
# 6. region

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_4c340_row10_col0, #T_4c340_row10_col1, #T_4c340_row10_col2, #T_4c340_row10_col3, #T_4c340_row10_col4, #T_4c340_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4c340">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c340_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4c340_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4c340_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4c340_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4c340_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4c340_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(lr)

# %%
save_model(lr, 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['sex', 'smoker'],
#                                      transfor...
#                                                                use_cat_names=True))),
#                  ('polynomial_features',
#                   TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                  ('bin_numeric_features',
#                   TransformerWrapper(include=['age', 'bmi'],
# ...

# %%
deployment_28042020 = load_model('deployment_28042020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
deployment_28042020
# Out:
# [Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  numeric_strategy='mean',
#                                  target_variable=None)),
#                  ('new_levels1',
#                   New_Catagorical_Levels...
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', Empty()), ('fix_multi', Empty()),
#                  ('dfs',
# ...

# %%
import requests
url = 'https://pycaret-insurance.herokuapp.com/predict_api'
pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
print(pred.json())
# Out:
# 75714.0
